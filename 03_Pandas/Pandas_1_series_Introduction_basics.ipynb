# %% [markdown]
# # Topic - 1 : Why Pandas?

# %% [raw]
# import datasets
# Data cleaning
# Size Mutability
# Reshaping and Pivoting Datasets
# Efficient Manipulation and Extraction
# Statistical Analysis

# %% [markdown]
# ###

# %% [markdown]
# # Topic - 2 : Two primary Data Structures

# %% [markdown]
# Data Structures are collections of the datatypes that provide the best way of organizing items(Values) in terms of memory usage.

# %% [raw]
# 1. Series      --> 1D --> Represent 1 Row of the dataset
#                --> It has one index column and one data column
#                --> It is homogenous array means collection of the data with same datatype.
#                --> It is immutable in length means you can perform add or remove element operation but after that operation change is not done in current but you returned new copy of the series.
#
#
# 2. Data frames --> 2D --> Represent entire dataset
#                --> It has one index column and many data columns
#                --> It is heterogeneous arrays means many columns may have different types of datatypes data.
#                --> It is size mutable datastructure because you can add or remove columns or rows or element from current dataframe.

# %% [markdown]
# ###

# %% [markdown]
# # Topic - 3 : Let's Start with importing pandas

# %%
import pandas as pd

# %% [markdown]
# ###

# %% [markdown]
# # Topic - 4 : Creation of series in the pandas

# %%
s = pd.Series([10,20,30,40,50])

# %%
s  # we can see here that 1st column shows indices and 2nd column shows values according to indices
    # Current datatype of each element is int but what if I add one string element...
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s1 = pd.Series([10,20,30,40,50,'abc'])

# %%
s1 # we can see that current datatype of the series is object now..
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50
# 5    abc
# dtype: object

# %%
s.dtype # to check datatype of the series..
# Out:
# dtype('int64')

# %%
s.values # to check the values have a series..
# Out:
# array([10, 20, 30, 40, 50], dtype=int64)

# %%
s.index # to check what is the range of the values through index start, stop and step..
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(s.name) # Give name to series
# Out:
# None

# %%
s.name = "Numbers"

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Numbers, dtype: int64
